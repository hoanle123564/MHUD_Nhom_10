# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('./magic+gamma+telescope/magic04.data', header=None)
df.columns = [
    "fLength", "fWidth", "fSize", "fConc", "fConc1", 
    "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"
]

df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %% [markdown]
# ## Phân bố nhãn (class)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='class')
plt.title("Phân bố nhãn (g vs h)")
plt.xlabel("Class")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fLength**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fLength'], kde=True, bins=30)
plt.title("Histogram của fLength")
plt.xlabel("fLength")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fWidth**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fWidth'], kde=True, bins=30)
plt.title("Histogram của fWidth")
plt.xlabel("fWidth")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fSize**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fSize'], kde=True, bins=30)
plt.title("Histogram của fSize")
plt.xlabel("fSize")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fConc**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fConc'], kde=True, bins=30)
plt.title("Histogram của fConc")
plt.xlabel("fConc")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fConc1**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fConc1'], kde=True, bins=30)
plt.title("Histogram của fConc1")
plt.xlabel("fConc1")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fAsym**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fAsym'], kde=True, bins=30)
plt.title("Histogram của fAsym")
plt.xlabel("fAsym")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fM3Long**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fM3Long'], kde=True, bins=30)
plt.title("Histogram của fM3Long")
plt.xlabel("fM3Long")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fM3Trans**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fM3Trans'], kde=True, bins=30)
plt.title("Histogram của fM3Trans")
plt.xlabel("fM3Trans")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fAlpha**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fAlpha'], kde=True, bins=30)
plt.title("Histogram của fAlpha")
plt.xlabel("fAlpha")
plt.ylabel("Số lượng")
plt.show()

# %% [markdown]
# ## Phân bố thuộc tính **fDist**

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['fDist'], kde=True, bins=30)
plt.title("Histogram của fDist")
plt.xlabel("fDist")
plt.ylabel("Số lượng")
plt.show()
